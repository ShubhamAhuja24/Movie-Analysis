# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamAhuja24/Movie-Analysis/blob/main/Movie_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.read_csv("IMDB top 1000.csv")
df.head()
# Out:
#    Unnamed: 0                                              Title Certificate  \
# 0           0                 1. The Shawshank Redemption (1994)           R
# 1           1                            2. The Godfather (1972)           R
# 2           2                          3. The Dark Knight (2008)       PG-13
# 3           3                   4. The Godfather: Part II (1974)           R
# 4           4  5. The Lord of the Rings: The Return of the Ki...       PG-13
#
#   Duration                     Genre  Rate  Metascore  \
# 0  142 min                     Drama   9.3       80.0
# 1  175 min              Crime, Drama   9.2      100.0
# 2  152 min      Action, Crime, Drama   9.0       84.0
# 3  202 min              Crime, Drama   9.0       90.0
# 4  201 min  Action, Adventure, Drama   8.9       94.0
#
#                                          Description  \
# 0  Two imprisoned men bond over a number of years...
# 1  The aging patriarch of an organized crime dyna...
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# Title           object
# Certificate     object
# Duration        object
# Genre           object
# Rate           float64
# Metascore      float64
# Description     object
# Cast            object
# Info            object
# dtype: object

# %%
df.shape
# Out:
# (1000, 10)

# %%
print("Number of rows are ", df.shape[0])
print('Number of columns are', df.shape[1])
# Out:
# Number of rows are  1000
# Number of columns are 10

# %%
print("Any missing value",df.isnull().values.any())
df.isnull()
# Out:
# Any missing value True
#      Unnamed: 0  Title  Certificate  Duration  Genre   Rate  Metascore  \
# 0         False  False        False     False  False  False      False
# 1         False  False        False     False  False  False      False
# 2         False  False        False     False  False  False      False
# 3         False  False        False     False  False  False      False
# 4         False  False        False     False  False  False      False
# ..          ...    ...          ...       ...    ...    ...        ...
# 995       False  False        False     False  False  False       True
# 996       False  False        False     False  False  False      False
# 997       False  False        False     False  False  False      False
# 998       False  False        False     False  False  False       True
# 999       False  False        False     False  False  False       True
#
#      Description   Cast   Info
# 0          False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# Title            0
# Certificate     27
# Duration         0
# Genre            0
# Rate             0
# Metascore      288
# Description      0
# Cast             0
# Info             0
# dtype: int64

# %%
import seaborn as sns

sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# percentage of missing data

per_miss = df.isnull().sum()*100/len(df)
per_miss
# Out:
# Unnamed: 0      0.0
# Title           0.0
# Certificate     2.7
# Duration        0.0
# Genre           0.0
# Rate            0.0
# Metascore      28.8
# Description     0.0
# Cast            0.0
# Info            0.0
# dtype: float64

# %%
# dropping the missing values

df.dropna(axis=0, inplace=True)
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Title          0
# Certificate    0
# Duration       0
# Genre          0
# Rate           0
# Metascore      0
# Description    0
# Cast           0
# Info           0
# dtype: int64

# %%
# searching for duplicate data

dup_df = df.duplicated().any()

dup_df
# Out:
# False

# %%
# statisfical representation of overall data

df.describe(include='all')
# Out:
#         Unnamed: 0            Title Certificate Duration  Genre        Rate  \
# count   712.000000              712         712      712    712  712.000000
# unique         NaN              286          10      103    109         NaN
# top            NaN  400. JFK (1991)           R  108 min  Drama         NaN
# freq           NaN                7         300       29     67         NaN
# mean    495.816011              NaN         NaN      NaN    NaN    8.103511
# std     292.868741              NaN         NaN      NaN    NaN    0.187969
# min       0.000000              NaN         NaN      NaN    NaN    8.000000
# 25%     242.750000              NaN         NaN      NaN    NaN    8.000000
# 50%     496.500000              NaN         NaN      NaN    NaN    8.000000
# 75%     751.250000              NaN         NaN      NaN    NaN    8.100000
# max     997.000000              NaN         NaN      NaN    NaN    9.300000
#
# ...

# %%
# stats for all columns

df.describe()
# Out:
#        Unnamed: 0        Rate   Metascore
# count  712.000000  712.000000  712.000000
# mean   495.816011    8.103511   81.001404
# std    292.868741    0.187969    9.811801
# min      0.000000    8.000000   61.000000
# 25%    242.750000    8.000000   73.000000
# 50%    496.500000    8.000000   82.000000
# 75%    751.250000    8.100000   88.250000
# max    997.000000    9.300000  100.000000

# %%
relations = df.corr()["Rate"].sort_values()
sns.regplot(data=df, x= "Metascore", y = "Rate")
# Out:
# <ipython-input-19-81eb5ae8ff4e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   relations = df.corr()["Rate"].sort_values()
# <Axes: xlabel='Metascore', ylabel='Rate'>

# %%
relations
# Out:
# Unnamed: 0   -0.678050
# Metascore     0.183936
# Rate          1.000000
# Name: Rate, dtype: float64

# %%
df[df["Genre"]=="Drama"]
# Out:
#      Unnamed: 0                                       Title Certificate  \
# 0             0          1. The Shawshank Redemption (1994)           R
# 9             9                       10. Fight Club (1999)           R
# 18           18  19. One Flew Over the Cuckoo's Nest (1975)           R
# 39           39               40. American History X (1998)           R
# 44           44                  45. Cinema Paradiso (1988)           R
# ..          ...                                         ...         ...
# 965         965                      368. The Return (2003)   Not Rated
# 979         979                        382. Magnolia (1999)           R
# 984         984                 387. The Celebration (1998)           R
# 985         985                 388. Central Station (1998)           R
# 988         988                     391. Sling Blade (1996)           R
#
#     Duration  Genre  Rate  Metascore  \
# 0    142 min  Drama   9.3       80.0
# ...

# %%
df['Duration'].value_counts()
# Out:
# 108 min    29
# 115 min    24
# 137 min    24
# 113 min    22
# 143 min    21
#            ..
# 172 min     1
# 321 min     1
# 162 min     1
# 207 min     1
# 81 min      1
# Name: Duration, Length: 103, dtype: int64
